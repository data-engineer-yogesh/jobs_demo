# %%
print("This is a notebook number 1")

# %%
dbutils.widgets.get("football_team")

# %%
df_print = dbutils.jobs.taskValues.set(key="records_processed", value=5)

# %%
print(df_print)

# %%
job_id = dbutils.widgets.get("current_job_id")
task_key = dbutils.widgets.get("current_task_key")
run_id = dbutils.widgets.get("current_run_id")


print(f"Databricks Job ID: {job_id}")
print(f"Databricks Task Key: {task_key}")
print(f"Databricks Run ID: {run_id}")
