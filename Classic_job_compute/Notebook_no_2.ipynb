# %%
print("This is a notebook number 2")

# %%
df_print = dbutils.jobs.taskValues.get(taskKey="Notebook_no_1",
                                 key="records_processed", 
                                 default="default_value", 
                                 debugValue=None)

# %%
print(df_print)
