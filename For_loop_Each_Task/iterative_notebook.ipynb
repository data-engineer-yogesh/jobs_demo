# %%
regoin_name = dbutils.widgets.get("regoin_name")

# %%
print(regoin_name)

# %%
spark.read.table("population_metrics.default.countries_consolidated").filter(f"region = '{regoin_name}'").display()
